# %%
#init stuff
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

# %%
def fit_hdb(ref, hdb_ref):
    root = '../resources/'
    avai = pd.read_csv(f'{root}{ref}').drop('Unnamed: 0', axis=1)
    hdb = pd.read_csv(f'{root}{hdb_ref}')
    return pd.merge(avai, hdb, left_on='number', right_on='car_park_no')

# %%
hdb = pd.read_csv('../resources/hdb-carpark-information.csv')
hdb.plot(kind='scatter', x='x_coord', y='y_coord')
# Out:
# <AxesSubplot:xlabel='x_coord', ylabel='y_coord'>
